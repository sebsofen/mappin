# %% [markdown]
# For a given point, determine Country and set pin in country.
#
# For country borders, use Natural-Earth in geojson format from this repository https://github.com/nvkelso/natural-earth-vector/tree/master/geojson

# %%
import json
from shapely.geometry import shape, Point
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import urllib.parse, base64
from IPython.core.display import display, HTML

from IPython.display import SVG

from mapautopin import pointstomap

# %%
points = [[-88.2052656, 20.6764001], [-118.220006,51.237181]]

# %%
with open('testlocations.json', 'r') as f:
    locations_json = json.load(f)

points = [[x['location']['cnt']['latLon']['lon'], x['location']['cnt']['latLon']['lat']] for x in locations_json][-1:]

# %%
imgdata = pointstomap.pointstomap(points)
